# %%
# %pip install -r requirements.txt

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import time
import yfinance as yf

import glob
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
import pickle

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import layers,models

# %%
# making the dataframe of csv file names in the directory
directory="./"
csv_files=glob.glob(os.path.join(directory,"*.csv"))
print(csv_files)
fileName_Df=pd.DataFrame()
L=[]
for file in csv_files:
    filename = os.path.splitext(os.path.basename(file))[0]
    L.append(filename+".csv")
print(L) 
fileName_Df["files"]=L   
fileName_Df
# Out:
# ['.\\allStocks_df.csv', '.\\MW-NIFTY-50-26-Jan-2025.csv', '.\\MW-NIFTY-MIDCAP-150-10-Feb-2025.csv', '.\\MW-NIFTY-MIDSMALLCAP-400-10-Feb-2025.csv', '.\\MW-NIFTY-SMALLCAP-250-10-Feb-2025.csv', '.\\MW-NIFTY-TOTAL-MARKET-10-Feb-2025.csv', '.\\MW-NIFTY500-MULTICAP-50_25_25-10-Feb-2025.csv']
# ['allStocks_df.csv', 'MW-NIFTY-50-26-Jan-2025.csv', 'MW-NIFTY-MIDCAP-150-10-Feb-2025.csv', 'MW-NIFTY-MIDSMALLCAP-400-10-Feb-2025.csv', 'MW-NIFTY-SMALLCAP-250-10-Feb-2025.csv', 'MW-NIFTY-TOTAL-MARKET-10-Feb-2025.csv', 'MW-NIFTY500-MULTICAP-50_25_25-10-Feb-2025.csv']
#                                            files
# 0                               allStocks_df.csv
# 1                    MW-NIFTY-50-26-Jan-2025.csv
# 2            MW-NIFTY-MIDCAP-150-10-Feb-2025.csv
# 3       MW-NIFTY-MIDSMALLCAP-400-10-Feb-2025.csv
# 4          MW-NIFTY-SMALLCAP-250-10-Feb-2025.csv
# 5          MW-NIFTY-TOTAL-MARKET-10-Feb-2025.csv
# 6  MW-NIFTY500-MULTICAP-50_25_25-10-Feb-2025.csv

# %%
#Extracting all symbols from all files and removing duplicates using set
stockNamesSet=set()
stockNamesSetwithNS=set()
stockSymbols_df=pd.DataFrame()
stockSymbols_df["Symbols"]=[]
max=0
for i in range(1,len(L)):
    df=pd.read_csv(fileName_Df["files"][i])
    max=len(df["SYMBOL \n"][1:])
    for j in range(1,max):
        stockNamesSetwithNS.add(df["SYMBOL \n"][j]+".NS")
        stockNamesSet.add(df["SYMBOL \n"][j])
print(stockNamesSet)
print(stockNamesSetwithNS)
print(len(stockNamesSet))
stockNamesSetList=list(stockNamesSet)
stockNamesSetList=sorted(stockNamesSetList)
print(stockNamesSetList)
stockSymbols_df["Symbols"]=stockNamesSetList
stockSymbols_df.head()
# Out:
# {'IPCALAB', 'TATAINVEST', 'DEEPAKFERT', 'VSTIND', 'THERMAX', 'TCIEXP', 'MIDHANI', 'PARAS', 'INDHOTEL', 'GRSE', 'GNFC', 'FSL', 'VENKEYS', 'SSWL', 'AMBUJACEM', 'MRF', 'PGHL', 'ZOMATO', 'HSCL', 'RAMCOCEM', 'FINCABLES', 'ZYDUSLIFE', 'WONDERLA', 'TVSSCS', 'PEL', 'ELGIEQUIP', 'RTNINDIA', 'TCS', 'CIGNITITEC', 'THOMASCOOK', 'BBTC', 'TEJASNET', 'HDFCBANK', 'DCAL', 'EMUDHRA', 'MUTHOOTFIN', 'TRIDENT', 'CGPOWER', 'HEMIPROP', 'ADANIGREEN', 'INDUSTOWER', 'METROBRAND', 'SCHAEFFLER', 'LTFOODS', 'POLICYBZR', 'SIGNATURE', 'MAITHANALL', 'HBLENGINE', 'TIMKEN', 'GOPAL', 'CEATLTD', 'ZEEL', 'SAMMAANCAP', 'TATACHEM', 'FLUOROCHEM', 'COROMANDEL', 'LMW', 'LUPIN', 'HOMEFIRST', 'RKFORGE', 'DRREDDY', 'NCC', 'NSLNISP', 'UNOMINDA', 'RENUKA', 'SYMPHONY', 'CONCORDBIO', 'MMTC', 'KALYANKJIL', 'ASHOKLEY', 'COCHINSHIP', 'TATASTEEL', 'FORCEMOT', 'ROUTE', 'BIRLACORPN', 'LICI', 'RELIGARE', 'MEDPLUS', 'SAPPHIRE', 'APLLTD', 'BALAMINES', 'DBL', 'ZYDUSWELL', 'GSPL', 'VOLTAMP', 'CANFINHOME', 'GREAVESCOT', 'NETWORK18', 'TI', 'PURVA', 'SJVN', 'JTEKTINDIA', 'HINDZINC', 'BALKRISIND', 'GRAPHITE', 'RAILTEL', 'TIINDIA', 'SANGHVIMOV', 'PAYTM', 'EPL', 'JSL', 'SANOFI', 'EXIDEIND', 'SUPRIYA', 'MRPL', 'DELHIVERY', 'CREDITACC', 'CLEAN', 'CELLO', 'MTARTECH', 'SIEMENS', 'UCOBANK', 'ACC', 'SUNDARMFIN', 'KNRCON', 'CIEINDIA', 'KOTAKBANK', 'LINDEINDIA', 'KIMS', 'ENTERO', 'METROPOLIS', 'BHEL', 'LTIM', 'GPPL', 'ROLEXRINGS', 'MAHLIFE', 'ORIENTELEC', 'ITI', 'SCHNEIDER', 'SKFINDIA', 'RVNL', 'KSCL', 'ANANDRATHI', 'RADICO', 'GATEWAY', 'BAJAJELEC', 'APLAPOLLO', 'JMFINANCIL', 'HAPPSTMNDS', 'CUB', 'TEXRAIL', 'KEC', 'UTIAMC', 'INDGN', 'JSFB', 'MANINFRA', 'ICIL', 'TIPSMUSIC', 'OIL', 'SYNGENE', 'MFSL', 'TECHNOE', 'RAJESHEXPO', 'AVANTIFEED', 'GODREJCP', 'SPLPETRO', 'INDIANB', 'BECTORFOOD', 'TATACOMM', 'GRWRHITECH', 'ECLERX', 'PPLPHARMA', 'VEEDOL', 'MSTCLTD', 'PGHH', 'HCLTECH', 'CHAMBLFERT', 'TECHM', 'EMAMILTD', 'ASTRAZEN', 'POWERMECH', 'ALOKINDS', 'GODREJPROP', 'FIVESTAR', 'AETHER', 'KRBL', 'DREAMFOLKS', 'MASTEK', 'GRINDWELL', 'CONFIPET', 'AARTIIND', 'CARTRADE', 'PARKHOTELS', 'EASEMYTRIP', 'DLF', 'HNDFDS', 'ICICIGI', 'INDIGOPNTS', 'SUDARSCHEM', 'INGERRAND', 'NUVAMA', 'GLAXO', 'PNBHOUSING', 'HAPPYFORGE', 'MSUMI', 'INDIAMART', 'MARICO', 'SINDHUTRAD', 'SENCO', 'EMIL', 'TATATECH', 'IONEXCHANG', 'LUXIND', 'JKLAKSHMI', 'SHARDAMOTR', 'AJANTPHARM', 'ANANTRAJ', 'YESBANK', 'VIPIND', 'KSB', 'BORORENEW', 'WELENT', 'ULTRACEMCO', 'LATENTVIEW', 'SCI', 'PAGEIND', 'APTUS', 'DIXON', 'POWERINDIA', 'SYRMA', 'IOC', 'ACI', 'PETRONET', 'GOCOLORS', 'ISGEC', 'PTCIL', 'ALKEM', 'NEULANDLAB', 'RAINBOW', 'HAL', 'MEDANTA', 'SAREGAMA', 'DEN', 'VMART', 'GLENMARK', 'NESCO', 'TEAMLEASE', 'OBEROIRLTY', 'WELCORP', 'DHANI', 'SUNTV', 'TEGA', 'BEL', 'EICHERMOT', 'CENTRALBK', 'INTELLECT', 'JINDWORLD', 'POLYPLEX', 'KANSAINER', 'MUTHOOTMF', 'NHPC', 'GRINFRA', 'HCG', 'COFORGE', 'LXCHEM', 'NAVA', 'JKTYRE', 'HARSHA', 'BLS', 'HINDOILEXP', 'KPIL', 'NAUKRI', 'DCBBANK', 'POWERGRID', 'DODLA', 'ADVENZYMES', 'NATCOPHARM', 'EIDPARRY', 'RAYMOND', 'LALPATHLAB', 'JYOTICNC', 'FCL', 'IXIGO', 'HDFCLIFE', 'STARCEMENT', 'IFBIND', 'ADANIPOWER', 'NH', 'ASTRAMICRO', 'FEDERALBNK', 'BAJFINANCE', 'DCMSHRIRAM', 'RATEGAIN', 'M&M', 'KPRMILL', 'MAPMYINDIA', 'SAMHI', 'PERSISTENT', 'BAJAJHIND', 'PATELENG', 'JYOTHYLAB', 'PRUDENT', 'IGL', 'REDINGTON', 'TRENT', 'AUROPHARMA', 'IRCON', 'EPIGRAL', 'KFINTECH', 'BLUEDART', 'TORNTPHARM', 'PRESTIGE', 'SRF', 'LANDMARK', 'RBA', 'MOIL', 'REDTAPE', 'VEDL', 'GODIGIT', 'ALLCARGO', 'ICICIPRULI', 'DOMS', 'POLYMED', 'PRICOLLTD', 'GODREJIND', 'ASAHIINDIA', 'KARURVYSYA', 'BAJAJCON', 'KALAMANDIR', 'CERA', 'BSE', 'INDIGO', 'BAJAJ-AUTO', 'DHANUKA', 'NESTLEIND', 'TATAPOWER', 'SUMICHEM', 'MAZDOCK', 'IFCI', 'ISEC', 'QUESS', 'IIFLCAPS', 'DALBHARAT', 'ADANIPORTS', 'INDUSINDBK', 'POLYCAB', 'TORNTPOWER', 'STLTECH', 'ORIENTCEM', 'JIOFIN', 'M&MFIN', 'ONGC', 'GRANULES', 'UJJIVANSFB', 'DATAMATICS', 'BANKINDIA', 'IEX', 'KPITTECH', 'VTL', 'HAVELLS', 'INFIBEAM', 'VAIBHAVGBL', 'GABRIEL', 'VESUVIUS', 'SBFC', 'SWANENERGY', 'JINDALSAW', 'RESPONIND', 'DATAPATTNS', 'JA ...
# {'SOBHA.NS', 'WELSPUNLIV.NS', 'EIDPARRY.NS', 'ROUTE.NS', 'NETWEB.NS', 'RCF.NS', 'TATACOMM.NS', 'BAJAJELEC.NS', 'PTCIL.NS', 'RADICO.NS', 'RAMKY.NS', 'DCAL.NS', 'CEATLTD.NS', 'BLUEDART.NS', 'CHOICEIN.NS', 'SHAREINDIA.NS', 'AUBANK.NS', 'RATNAMANI.NS', 'DHANUKA.NS', 'SUNDRMFAST.NS', 'SYRMA.NS', 'KAJARIACER.NS', 'LTF.NS', 'ABBOTINDIA.NS', 'ADANIENSOL.NS', 'BAJAJ-AUTO.NS', 'KANSAINER.NS', 'APOLLOHOSP.NS', 'BANKBARODA.NS', 'INTELLECT.NS', 'ANANTRAJ.NS', 'OBEROIRLTY.NS', 'THOMASCOOK.NS', 'MMTC.NS', 'IDEA.NS', 'CANFINHOME.NS', 'HONASA.NS', 'JUBLPHARMA.NS', 'SKFINDIA.NS', 'GRAVITA.NS', 'ICICIBANK.NS', 'ABSLAMC.NS', 'CREDITACC.NS', 'TEGA.NS', 'ARVINDFASN.NS', 'EMUDHRA.NS', 'ZENTEC.NS', 'HIKAL.NS', 'BEL.NS', 'AZAD.NS', 'IFBIND.NS', 'LTTS.NS', 'AMBUJACEM.NS', 'ELGIEQUIP.NS', 'JSFB.NS', 'DELTACORP.NS', 'CYIENT.NS', 'AKUMS.NS', 'AAVAS.NS', 'ELECON.NS', 'ARE&M.NS', 'PAGEIND.NS', 'KIRLPNU.NS', 'NAUKRI.NS', 'ADANIPOWER.NS', 'TCS.NS', 'HSCL.NS', 'DBREALTY.NS', 'VBL.NS', 'COALINDIA.NS', 'MAPMYINDIA.NS', 'ITC.NS', 'MAZDOCK.NS', 'FUSION.NS', 'RTNINDIA.NS', 'BRIGADE.NS', 'SUMICHEM.NS', 'KOLTEPATIL.NS', 'DISHTV.NS', 'JCHAC.NS', 'JIOFIN.NS', 'HINDOILEXP.NS', 'LAURUSLABS.NS', 'LATENTVIEW.NS', 'AHLUCONT.NS', 'PATANJALI.NS', 'LINDEINDIA.NS', 'SJVN.NS', 'BALKRISIND.NS', 'BALRAMCHIN.NS', 'KAYNES.NS', 'INDIGO.NS', 'SURYAROSNI.NS', 'NBCC.NS', 'TATACHEM.NS', 'SBFC.NS', 'YATHARTH.NS', 'EXIDEIND.NS', 'EMBDL.NS', 'SCHAEFFLER.NS', 'ARVIND.NS', 'EMIL.NS', 'JMFINANCIL.NS', 'CIPLA.NS', 'CELLO.NS', 'SULA.NS', 'MPHASIS.NS', 'KRBL.NS', 'TCIEXP.NS', 'DEN.NS', 'JKIL.NS', 'BDL.NS', 'ABCAPITAL.NS', 'SUNTECK.NS', 'CENTRALBK.NS', 'EICHERMOT.NS', 'JSWENERGY.NS', 'ISEC.NS', 'BLUESTARCO.NS', 'PRICOLLTD.NS', 'POLYCAB.NS', 'VENUSPIPES.NS', 'JWL.NS', 'AVALON.NS', 'CUMMINSIND.NS', 'VTL.NS', 'GNFC.NS', 'CGPOWER.NS', 'PATELENG.NS', 'CHENNPETRO.NS', 'NOCIL.NS', 'SHARDAMOTR.NS', 'SCI.NS', 'RATEGAIN.NS', 'GMMPFAUDLR.NS', 'ADANIGREEN.NS', 'RESPONIND.NS', 'KALAMANDIR.NS', 'BALMLAWRIE.NS', 'ACC.NS', 'WOCKPHARMA.NS', 'AARTIIND.NS', 'ESCORTS.NS', 'ABFRL.NS', 'BECTORFOOD.NS', 'EMAMILTD.NS', 'ORIENTELEC.NS', 'MFSL.NS', 'LLOYDSENGG.NS', 'SUZLON.NS', 'METROBRAND.NS', 'BIKAJI.NS', 'PVRINOX.NS', 'KPIL.NS', 'ALOKINDS.NS', 'PPLPHARMA.NS', '3MINDIA.NS', 'MSTCLTD.NS', 'JLHL.NS', 'HGINFRA.NS', 'IRCON.NS', 'SYMPHONY.NS', 'DBL.NS', 'GLAXO.NS', 'ENTERO.NS', 'EQUITASBNK.NS', 'GPPL.NS', 'ZFCVINDIA.NS', 'EIHOTEL.NS', 'FACT.NS', 'IOC.NS', 'CHOLAFIN.NS', 'CAPLIPOINT.NS', 'IIFL.NS', 'DEEPAKNTR.NS', 'FDC.NS', 'STAR.NS', 'HDFCAMC.NS', 'SWANENERGY.NS', 'SAREGAMA.NS', 'TEXRAIL.NS', 'JSL.NS', 'UNIONBANK.NS', 'PGEL.NS', 'ATGL.NS', 'ASTRAZEN.NS', 'JBMA.NS', 'SOLARINDS.NS', 'STLTECH.NS', 'JINDALSTEL.NS', 'ACI.NS', 'ALKEM.NS', 'TECHNOE.NS', 'AARTIPHARM.NS', 'SANOFI.NS', 'KSL.NS', 'PEL.NS', 'JINDALSAW.NS', 'MEDPLUS.NS', 'BSE.NS', 'TIINDIA.NS', 'MGL.NS', 'BIOCON.NS', 'HBLENGINE.NS', 'ASTERDM.NS', 'SSWL.NS', 'BAJAJHIND.NS', 'STARHEALTH.NS', 'MSUMI.NS', 'INOXGREEN.NS', 'NIACL.NS', 'CHALET.NS', 'BOROLTD.NS', 'TARC.NS', 'CAMS.NS', 'IRFC.NS', 'CIGNITITEC.NS', 'STARCEMENT.NS', 'HDFCLIFE.NS', 'EPL.NS', 'VOLTAS.NS', 'JAMNAAUTO.NS', 'VIJAYA.NS', 'CONFIPET.NS', 'IREDA.NS', 'BHARTIHEXA.NS', 'NAVINFLUOR.NS', 'DATAMATICS.NS', 'SAMMAANCAP.NS', 'NATCOPHARM.NS', 'RAINBOW.NS', 'HFCL.NS', 'DCMSHRIRAM.NS', 'GAIL.NS', 'BHARATFORG.NS', 'NAZARA.NS', 'MIDHANI.NS', 'GODREJCP.NS', 'MRPL.NS', 'LTFOODS.NS', 'NEWGEN.NS', 'BAJAJCON.NS', 'SPARC.NS', 'KPRMILL.NS', 'DLF.NS', 'BLS.NS', 'INDIAGLYCO.NS', 'ENDURANCE.NS', 'ORCHPHARMA.NS', 'PIIND.NS', 'RHIM.NS', 'JSWSTEEL.NS', 'INDGN.NS', 'IDFCFIRSTB.NS', 'AGI.NS', 'CANBK.NS', 'BRITANNIA.NS', 'REDTAPE.NS', 'DATAPATTNS.NS', 'KIRLOSENG.NS', 'USHAMART.NS', 'TIPSMUSIC.NS', 'KEI.NS', 'VESUVIUS.NS', 'DYNAMATECH.NS', 'SAFARI.NS', 'RECLTD.NS', 'GRASIM.NS', 'RELINFRA.NS', 'JAIBALAJI.NS', 'INDIACEM.NS', 'MANINFRA.NS', 'DRREDDY.NS', 'HDFCBANK.NS', 'GATEWAY.NS', 'BEML.NS', 'AADHARHFC.NS', 'BOSCHLTD.NS', 'NEOGEN.NS', 'ELECTCAST.NS', 'MEDANTA.NS', 'CENTURYPLY.NS', 'SPLPETRO.NS', 'NEULANDLAB.NS', 'WONDERLA.NS', 'J&KBANK.NS' ...
# 749
# ['360ONE', '3MINDIA', 'AADHARHFC', 'AARTIDRUGS', 'AARTIIND', 'AARTIPHARM', 'AAVAS', 'ABB', 'ABBOTINDIA', 'ABCAPITAL', 'ABFRL', 'ABREL', 'ABSLAMC', 'ACC', 'ACE', 'ACI', 'ADANIENSOL', 'ADANIENT', 'ADANIGREEN', 'ADANIPORTS', 'ADANIPOWER', 'ADVENZYMES', 'AEGISLOG', 'AETHER', 'AFFLE', 'AGI', 'AHLUCONT', 'AIAENG', 'AJANTPHARM', 'AKUMS', 'ALIVUS', 'ALKEM', 'ALKYLAMINE', 'ALLCARGO', 'ALOKINDS', 'AMBER', 'AMBUJACEM', 'AMIORG', 'ANANDRATHI', 'ANANTRAJ', 'ANGELONE', 'ANURAS', 'APARINDS', 'APLAPOLLO', 'APLLTD', 'APOLLOHOSP', 'APOLLOTYRE', 'APTUS', 'ARE&M', 'ARVIND', 'ARVINDFASN', 'ASAHIINDIA', 'ASHOKA', 'ASHOKLEY', 'ASIANPAINT', 'ASKAUTOLTD', 'ASTERDM', 'ASTRAL', 'ASTRAMICRO', 'ASTRAZEN', 'ATGL', 'ATUL', 'AUBANK', 'AUROPHARMA', 'AVALON', 'AVANTIFEED', 'AWL', 'AXISBANK', 'AZAD', 'BAJAJ-AUTO', 'BAJAJCON', 'BAJAJELEC', 'BAJAJFINSV', 'BAJAJHIND', 'BAJAJHLDNG', 'BAJFINANCE', 'BALAMINES', 'BALKRISIND', 'BALMLAWRIE', 'BALRAMCHIN', 'BANDHANBNK', 'BANKBARODA', 'BANKINDIA', 'BASF', 'BATAINDIA', 'BAYERCROP', 'BBL', 'BBTC', 'BDL', 'BECTORFOOD', 'BEL', 'BEML', 'BEPL', 'BERGEPAINT', 'BHARATFORG', 'BHARTIARTL', 'BHARTIHEXA', 'BHEL', 'BIKAJI', 'BIOCON', 'BIRLACORPN', 'BLS', 'BLUEDART', 'BLUEJET', 'BLUESTARCO', 'BOMDYEING', 'BOROLTD', 'BORORENEW', 'BOSCHLTD', 'BPCL', 'BRIGADE', 'BRITANNIA', 'BSE', 'BSOFT', 'CAMPUS', 'CAMS', 'CANBK', 'CANFINHOME', 'CAPLIPOINT', 'CARBORUNIV', 'CARTRADE', 'CASTROLIND', 'CCL', 'CDSL', 'CEATLTD', 'CELLO', 'CENTRALBK', 'CENTURYPLY', 'CERA', 'CESC', 'CGCL', 'CGPOWER', 'CHALET', 'CHAMBLFERT', 'CHEMPLASTS', 'CHENNPETRO', 'CHOICEIN', 'CHOLAFIN', 'CHOLAHLDNG', 'CIEINDIA', 'CIGNITITEC', 'CIPLA', 'CLEAN', 'CMSINFO', 'COALINDIA', 'COCHINSHIP', 'COFORGE', 'COLPAL', 'CONCOR', 'CONCORDBIO', 'CONFIPET', 'COROMANDEL', 'CRAFTSMAN', 'CREDITACC', 'CRISIL', 'CROMPTON', 'CSBBANK', 'CUB', 'CUMMINSIND', 'CYIENT', 'CYIENTDLM', 'DABUR', 'DALBHARAT', 'DATAMATICS', 'DATAPATTNS', 'DBL', 'DBREALTY', 'DCAL', 'DCBBANK', 'DCMSHRIRAM', 'DCXINDIA', 'DEEPAKFERT', 'DEEPAKNTR', 'DELHIVERY', 'DELTACORP', 'DEN', 'DEVYANI', 'DHANI', 'DHANUKA', 'DISHTV', 'DIVISLAB', 'DIXON', 'DLF', 'DMART', 'DODLA', 'DOMS', 'DREAMFOLKS', 'DRREDDY', 'DYNAMATECH', 'EASEMYTRIP', 'ECLERX', 'EDELWEISS', 'EICHERMOT', 'EIDPARRY', 'EIHOTEL', 'ELECON', 'ELECTCAST', 'ELGIEQUIP', 'EMAMILTD', 'EMBDL', 'EMCURE', 'EMIL', 'EMUDHRA', 'ENDURANCE', 'ENGINERSIN', 'ENTERO', 'EPIGRAL', 'EPL', 'EQUITASBNK', 'ERIS', 'ESAFSFB', 'ESCORTS', 'ETHOSLTD', 'EVEREADY', 'EXIDEIND', 'FACT', 'FCL', 'FDC', 'FEDERALBNK', 'FIEMIND', 'FINCABLES', 'FINEORG', 'FINPIPE', 'FIVESTAR', 'FLUOROCHEM', 'FORCEMOT', 'FORTIS', 'FSL', 'FUSION', 'GABRIEL', 'GAEL', 'GAIL', 'GANESHHOUC', 'GATEWAY', 'GESHIP', 'GHCL', 'GICRE', 'GILLETTE', 'GLAND', 'GLAXO', 'GLENMARK', 'GMDCLTD', 'GMMPFAUDLR', 'GMRAIRPORT', 'GNFC', 'GOCOLORS', 'GODFRYPHLP', 'GODIGIT', 'GODREJAGRO', 'GODREJCP', 'GODREJIND', 'GODREJPROP', 'GOKEX', 'GOPAL', 'GPIL', 'GPPL', 'GRANULES', 'GRAPHITE', 'GRASIM', 'GRAVITA', 'GREAVESCOT', 'GREENPANEL', 'GREENPLY', 'GRINDWELL', 'GRINFRA', 'GRSE', 'GRWRHITECH', 'GSFC', 'GSPL', 'GUJALKALI', 'GUJGASLTD', 'GULFOILLUB', 'GVT&D', 'HAL', 'HAPPSTMNDS', 'HAPPYFORGE', 'HARSHA', 'HATHWAY', 'HAVELLS', 'HBLENGINE', 'HCC', 'HCG', 'HCLTECH', 'HDFCAMC', 'HDFCBANK', 'HDFCLIFE', 'HEG', 'HEIDELBERG', 'HEMIPROP', 'HERITGFOOD', 'HEROMOTOCO', 'HFCL', 'HGINFRA', 'HIKAL', 'HINDALCO', 'HINDCOPPER', 'HINDOILEXP', 'HINDPETRO', 'HINDUNILVR', 'HINDWAREAP', 'HINDZINC', 'HNDFDS', 'HOMEFIRST', 'HONASA', 'HONAUT', 'HSCL', 'HUDCO', 'ICICIBANK', 'ICICIGI', 'ICICIPRULI', 'ICIL', 'IDBI', 'IDEA', 'IDEAFORGE', 'IDFCFIRSTB', 'IEX', 'IFBIND', 'IFCI', 'IGL', 'IIFL', 'IIFLCAPS', 'IMAGICAA', 'IMFA', 'INDGN', 'INDHOTEL', 'INDIACEM', 'INDIAGLYCO', 'INDIAMART', 'INDIANB', 'INDIASHLTR', 'INDIGO', 'INDIGOPNTS', 'INDUSINDBK', 'INDUSTOWER', 'INFIBEAM', 'INFY', 'INGERRAND', 'INOXGREEN', 'INOXINDIA', 'INOXWIND', 'INTELLECT', 'IOB', 'IOC', 'IONEXCHANG', 'IPCALAB', 'IPL', 'IRB', 'IRCON', 'IRCTC', 'IREDA', 'IRFC', 'ISEC', 'ISGEC', 'ITC', 'ITDCEM', 'ITI', 'IXIGO', 'J&KBANK', 'JAIBALAJI',  ...
#       Symbols
# 0      360ONE
# 1     3MINDIA
# 2   AADHARHFC
# 3  AARTIDRUGS
# 4    AARTIIND

# %%
NIFTY_50=[]
df1=pd.read_csv("MW-NIFTY-50-26-Jan-2025.csv")
NIFTY_50_Symbols=df1["SYMBOL \n"][1:]
print(NIFTY_50_Symbols,end=" ")
# Out:
# 1     HINDUNILVR
# 2      BRITANNIA
# 3      EICHERMOT
# 4         GRASIM
# 5      ICICIBANK
# 6     TATACONSUM
# 7          WIPRO
# 8          TECHM
# 9      POWERGRID
# 10          INFY
# 11     NESTLEIND
# 12    BHARTIARTL
# 13           ITC
# 14      JSWSTEEL
# 15           TCS
# 16          NTPC
# 17    BAJAJ-AUTO
# 18     TATASTEEL
# 19      HDFCLIFE
# 20         TITAN
# 21      HINDALCO
# 22    BAJFINANCE
# 23          SBIN
# 24      AXISBANK
# 25     COALINDIA
# 26    ASIANPAINT
# 27     KOTAKBANK
# 28       HCLTECH
# 29        MARUTI
# 30     SUNPHARMA
# 31    BAJAJFINSV
# 32    ADANIPORTS
# 33    SHRIRAMFIN
# 34       SBILIFE
# 35    ULTRACEMCO
# 36      HDFCBANK
# 37    HEROMOTOCO
# 38            LT
# 39           BEL
# 40      RELIANCE
# 41          ONGC
# 42    INDUSINDBK
# 43         CIPLA
# 44    TATAMOTORS
# 45    APOLLOHOSP
# 46          BPCL
# 47      ADANIENT
# 48           M&M
# 49         TRENT
# 50       DRREDDY
# Name: SYMBOL \n, dtype: object

# %%
NIFTY_MIDCAP_150=[]
df1=pd.read_csv("MW-NIFTY-MIDCAP-150-10-Feb-2025.csv")
NIFTY_MIDCAP_150=df1["SYMBOL \n"][1:]
print(NIFTY_MIDCAP_150)
# Out:
# 1      BERGEPAINT
# 2        UNOMINDA
# 3         PAGEIND
# 4         ESCORTS
# 5       SOLARINDS
#           ...
# 146    CARBORUNIV
# 147     DELHIVERY
# 148     MAXHEALTH
# 149    BHARTIHEXA
# 150         ALKEM
# Name: SYMBOL \n, Length: 150, dtype: object

# %%
NIFTY_MIDSMALL_400=[]
df1=pd.read_csv("MW-NIFTY-MIDSMALLCAP-400-10-Feb-2025.csv")
NIFTY_MIDSMALL_400=df1["SYMBOL \n"][1:]
print(NIFTY_MIDSMALL_400)
# Out:
# 1       REDINGTON
# 2       SIGNATURE
# 3          VARROC
# 4      AVANTIFEED
# 5        ANANTRAJ
#           ...
# 396    BHARTIHEXA
# 397         ALKEM
# 398    UJJIVANSFB
# 399    JMFINANCIL
# 400        NETWEB
# Name: SYMBOL \n, Length: 400, dtype: object

# %%
NIFTY_SMALL_250=[]
df1=pd.read_csv("MW-NIFTY-SMALLCAP-250-10-Feb-2025.csv")
NIFTY_SMALL_250=df1["SYMBOL \n"][1:]
print(NIFTY_SMALL_250)
# Out:
# 1       REDINGTON
# 2       SIGNATURE
# 3          VARROC
# 4      AVANTIFEED
# 5        ANANTRAJ
#           ...
# 246      FIVESTAR
# 247         SOBHA
# 248    UJJIVANSFB
# 249    JMFINANCIL
# 250        NETWEB
# Name: SYMBOL \n, Length: 250, dtype: object

# %%
NIFTY_MULTICAP_500=[]
df1=pd.read_csv("MW-NIFTY500-MULTICAP-50_25_25-10-Feb-2025.csv")
NIFTY_MULTICAP_500=df1["SYMBOL \n"][1:]
print(NIFTY_MULTICAP_500)
# Out:
# 1       REDINGTON
# 2       SIGNATURE
# 3          VARROC
# 4      AVANTIFEED
# 5        ANANTRAJ
#           ...
# 496    BHARTIHEXA
# 497         ALKEM
# 498    UJJIVANSFB
# 499    JMFINANCIL
# 500        NETWEB
# Name: SYMBOL \n, Length: 500, dtype: object

# %%
#checking the stock details
def get_info(ticker):
    stock=yf.Ticker(ticker)
    print(stock.info)

# %%
def save_csv(stock_name):
    stock=yf.Ticker(stock_name)
    df=stock.history(period="20y")["Close"]
    file=stock_name.replace(".NS","")+".csv"
    df.to_csv("data/"+file)

# %%
for stock in stockNamesSetwithNS:
    save_csv(stock)

# %%
# individually collected missing stock data and replaced

# %%
#combining all stocks data into a single dataframe
allStocks_df=pd.DataFrame()
date_purpose=pd.read_csv("data/VSTIND.csv")
allStocks_df["Date"]=date_purpose["Date"]
try:
    for i in stockNamesSet:
        dfs=pd.read_csv("data/"+i+".csv")
        allStocks_df=allStocks_df.merge(dfs,left_on="Date",right_on="Date",how="left")
        allStocks_df=allStocks_df.rename(columns={"Close":i})
               
except Exception as e:
    print("Error: ",e)

allStocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4938 entries, 0 to 4937
# Columns: 750 entries, Date to NUVOCO
# dtypes: float64(749), object(1)
# memory usage: 28.3+ MB

# %%
allStocks_df.to_csv("allStocks_df.csv")

# %%
allStocks_df
# Out:
#                            Date      IPCALAB   TATAINVEST   DEEPAKFERT  \
# 0     2005-02-14 00:00:00+05:30    33.619289   119.721344    30.200087
# 1     2005-02-15 00:00:00+05:30    33.516224   116.632416    29.136332
# 2     2005-02-16 00:00:00+05:30    33.748142   121.393723    28.487707
# 3     2005-02-17 00:00:00+05:30    33.859802   122.869354    29.603340
# 4     2005-02-18 00:00:00+05:30    32.601448   122.574219    29.162277
# ...                         ...          ...          ...          ...
# 4933  2025-02-07 00:00:00+05:30  1507.250000  5899.750000  1175.000000
# 4934  2025-02-10 00:00:00+05:30  1447.949951  5831.000000  1129.449951
# 4935  2025-02-11 00:00:00+05:30  1419.900024  5696.049805  1080.400024
# 4936  2025-02-12 00:00:00+05:30  1419.800049  5406.799805  1050.150024
# 4937  2025-02-13 00:00:00+05:30  1502.750000  5342.000000  1061.099976
#
#           VSTIND      THERMAX      TCIEXP     MIDHANI        PARAS  \
# 0       0.040776    17.947807         NaN         NaN          NaN
# 1       0.041653    17.756548         NaN         NaN          NaN
# 2       0.040458    18.056442         NaN         NaN          NaN
# 3       0.041175    17.528566         NaN         NaN          NaN
# 4       0.039864    17.546926         NaN         NaN          NaN
# ...          ...          ...         ...         ...          ...
# 4933  330.049988  3388.050049  747.285034  304.500000  1039.699951
# 4934  321.649994  3278.899902  722.636108  299.850006  1022.250000
# 4935  315.200012  3165.300049  731.450012  283.450012   989.049988
# 4936  304.149994  3181.600098  729.750000  279.250000   976.450012
# 4937  303.850006  3182.500000  727.849976  284.899994   975.049988
#
#         INDHOTEL  ...  CHEMPLASTS    CROMPTON      ARVIND     ZFCVINDIA  \
# 0      46.356495  ...         NaN         NaN   33.705025    697.312134
# 1      46.123627  ...         NaN         NaN   32.947613    698.173218
# 2      46.278858  ...         NaN         NaN   33.420994    681.766479
# 3      46.053757  ...         NaN         NaN   33.096382    683.823181
# 4      46.930901  ...         NaN         NaN   33.393948    677.844055
# ...          ...  ...         ...         ...         ...           ...
# 4933  791.799988  ...  461.700012  365.850006  372.399994  11867.700195
# 4934  776.700012  ...  453.350006  348.899994  347.549988  11738.750000
# 4935  748.000000  ...  433.700012  343.100006  332.700012  11228.450195
# 4936  731.200012  ...  428.350006  340.000000  335.600006  10989.450195
# 4937  735.900024  ...  424.049988  342.399994  330.350006  10847.450195
#
#              RCF       NBCC    JSWINFRA         ITC        IOB      NUVOCO
# 0      23.106863        NaN         NaN   18.367157  48.841972         NaN
# 1      22.525557        NaN         NaN   18.281515  48.260086         NaN
# 2      22.380232        NaN         NaN   18.177773  47.969143         NaN
# 3      23.426580        NaN         NaN   18.087257  46.078022         NaN
# 4      22.961538        NaN         NaN   17.825455  47.714573         NaN
# ...          ...        ...         ...         ...        ...         ...
# 4933  156.380005  92.480003  258.799988  424.154968  50.369999  359.500000
# 4934  150.389999  90.209999  256.600006  420.561707  49.529999  347.899994
# 4935  141.089996  85.360001  243.800003  411.799988  48.169998  336.799988
# 4936  140.070007  85.870003  236.399994  409.899994  47.740002  328.649994
# 4937  141.669998  85.639999  240.699997  410.700012  47.849998  329.049988
#
# [4938 rows x 750 columns]

# %%
#converting date to seconds format
allStocks_df.Date=pd.to_datetime(allStocks_df.Date)
allStocks_df.Date=allStocks_df.Date.astype("int64")//10**9
allStocks_df.head(2)
# Out:
#          Date    IPCALAB  TATAINVEST  DEEPAKFERT    VSTIND    THERMAX  TCIEXP  \
# 0  1108319400  33.619289  119.721344   30.200087  0.040776  17.947807     NaN
# 1  1108405800  33.516224  116.632416   29.136332  0.041653  17.756548     NaN
#
#    MIDHANI  PARAS   INDHOTEL  ...  CHEMPLASTS  CROMPTON     ARVIND  \
# 0      NaN    NaN  46.356495  ...         NaN       NaN  33.705025
# 1      NaN    NaN  46.123627  ...         NaN       NaN  32.947613
#
#     ZFCVINDIA        RCF  NBCC  JSWINFRA        ITC        IOB  NUVOCO
# 0  697.312134  23.106863   NaN       NaN  18.367157  48.841972     NaN
# 1  698.173218  22.525557   NaN       NaN  18.281515  48.260086     NaN
#
# [2 rows x 750 columns]

# %%
allStocks_df.isnull().sum()
# Out:
# Date             0
# IPCALAB          0
# TATAINVEST       0
# DEEPAKFERT       0
# VSTIND           0
#               ...
# NBCC          1770
# JSWINFRA      4604
# ITC              0
# IOB              0
# NUVOCO        4076
# Length: 750, dtype: int64

# %%
allStocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4938 entries, 0 to 4937
# Columns: 750 entries, Date to NUVOCO
# dtypes: float64(749), int64(1)
# memory usage: 28.3 MB

# %%
# finding the non null value of each stock 
allStocks_df.count()[2]
# Out:
# 4938

# %%
len(allStocks_df[listOfColumns[1]])
# Out:
# 4938

# %%
#making new dataframe by removing some null valued stocks/columns
#finding the number of null valued columns < 0.5*max
maximum=allStocks_df["Date"].count()
print(maximum)
columns_allStocks=allStocks_df.columns
listOfColumns=list(columns_allStocks)
print(listOfColumns)

modified_allStocks=pd.DataFrame()

listOfStocksHaveGreaterThanHalfData=[]
NumberOfColumnsHaveGreaterThanHalfData=0

for i in range(len(listOfColumns)):
    if allStocks_df.count()[i]>maximum*0.6:
        NumberOfColumnsHaveGreaterThanHalfData+=1
        listOfStocksHaveGreaterThanHalfData.append(listOfColumns[i])

# for i in listOfColumns:
#     if len(allStocks_df[i])<maximum*0.6:
#         NumberOfColumnsHaveGreaterThanHalfData+=1
#         listOfStocksHaveGreaterThanHalfData.append(i)

print(f"{NumberOfColumnsHaveGreaterThanHalfData}/{len(listOfColumns)}")
print(listOfStocksHaveGreaterThanHalfData)
# Out:
# 4938
# ['Date', 'IPCALAB', 'TATAINVEST', 'DEEPAKFERT', 'VSTIND', 'THERMAX', 'TCIEXP', 'MIDHANI', 'PARAS', 'INDHOTEL', 'GRSE', 'GNFC', 'FSL', 'VENKEYS', 'SSWL', 'AMBUJACEM', 'MRF', 'PGHL', 'ZOMATO', 'HSCL', 'RAMCOCEM', 'FINCABLES', 'ZYDUSLIFE', 'WONDERLA', 'TVSSCS', 'PEL', 'ELGIEQUIP', 'RTNINDIA', 'TCS', 'CIGNITITEC', 'THOMASCOOK', 'BBTC', 'TEJASNET', 'HDFCBANK', 'DCAL', 'EMUDHRA', 'MUTHOOTFIN', 'TRIDENT', 'CGPOWER', 'HEMIPROP', 'ADANIGREEN', 'INDUSTOWER', 'METROBRAND', 'SCHAEFFLER', 'LTFOODS', 'POLICYBZR', 'SIGNATURE', 'MAITHANALL', 'HBLENGINE', 'TIMKEN', 'GOPAL', 'CEATLTD', 'ZEEL', 'SAMMAANCAP', 'TATACHEM', 'FLUOROCHEM', 'COROMANDEL', 'LMW', 'LUPIN', 'HOMEFIRST', 'RKFORGE', 'DRREDDY', 'NCC', 'NSLNISP', 'UNOMINDA', 'RENUKA', 'SYMPHONY', 'CONCORDBIO', 'MMTC', 'KALYANKJIL', 'ASHOKLEY', 'COCHINSHIP', 'TATASTEEL', 'FORCEMOT', 'ROUTE', 'BIRLACORPN', 'LICI', 'RELIGARE', 'MEDPLUS', 'SAPPHIRE', 'APLLTD', 'BALAMINES', 'DBL', 'ZYDUSWELL', 'GSPL', 'VOLTAMP', 'CANFINHOME', 'GREAVESCOT', 'NETWORK18', 'TI', 'PURVA', 'SJVN', 'JTEKTINDIA', 'HINDZINC', 'BALKRISIND', 'GRAPHITE', 'RAILTEL', 'TIINDIA', 'SANGHVIMOV', 'PAYTM', 'EPL', 'JSL', 'SANOFI', 'EXIDEIND', 'SUPRIYA', 'MRPL', 'DELHIVERY', 'CREDITACC', 'CLEAN', 'CELLO', 'MTARTECH', 'SIEMENS', 'UCOBANK', 'ACC', 'SUNDARMFIN', 'KNRCON', 'CIEINDIA', 'KOTAKBANK', 'LINDEINDIA', 'KIMS', 'ENTERO', 'METROPOLIS', 'BHEL', 'LTIM', 'GPPL', 'ROLEXRINGS', 'MAHLIFE', 'ORIENTELEC', 'ITI', 'SCHNEIDER', 'SKFINDIA', 'RVNL', 'KSCL', 'ANANDRATHI', 'RADICO', 'GATEWAY', 'BAJAJELEC', 'APLAPOLLO', 'JMFINANCIL', 'HAPPSTMNDS', 'CUB', 'TEXRAIL', 'KEC', 'UTIAMC', 'INDGN', 'JSFB', 'MANINFRA', 'ICIL', 'TIPSMUSIC', 'OIL', 'SYNGENE', 'MFSL', 'TECHNOE', 'RAJESHEXPO', 'AVANTIFEED', 'GODREJCP', 'SPLPETRO', 'INDIANB', 'BECTORFOOD', 'TATACOMM', 'GRWRHITECH', 'ECLERX', 'PPLPHARMA', 'VEEDOL', 'MSTCLTD', 'PGHH', 'HCLTECH', 'CHAMBLFERT', 'TECHM', 'EMAMILTD', 'ASTRAZEN', 'POWERMECH', 'ALOKINDS', 'GODREJPROP', 'FIVESTAR', 'AETHER', 'KRBL', 'DREAMFOLKS', 'MASTEK', 'GRINDWELL', 'CONFIPET', 'AARTIIND', 'CARTRADE', 'PARKHOTELS', 'EASEMYTRIP', 'DLF', 'HNDFDS', 'ICICIGI', 'INDIGOPNTS', 'SUDARSCHEM', 'INGERRAND', 'NUVAMA', 'GLAXO', 'PNBHOUSING', 'HAPPYFORGE', 'MSUMI', 'INDIAMART', 'MARICO', 'SINDHUTRAD', 'SENCO', 'EMIL', 'TATATECH', 'IONEXCHANG', 'LUXIND', 'JKLAKSHMI', 'SHARDAMOTR', 'AJANTPHARM', 'ANANTRAJ', 'YESBANK', 'VIPIND', 'KSB', 'BORORENEW', 'WELENT', 'ULTRACEMCO', 'LATENTVIEW', 'SCI', 'PAGEIND', 'APTUS', 'DIXON', 'POWERINDIA', 'SYRMA', 'IOC', 'ACI', 'PETRONET', 'GOCOLORS', 'ISGEC', 'PTCIL', 'ALKEM', 'NEULANDLAB', 'RAINBOW', 'HAL', 'MEDANTA', 'SAREGAMA', 'DEN', 'VMART', 'GLENMARK', 'NESCO', 'TEAMLEASE', 'OBEROIRLTY', 'WELCORP', 'DHANI', 'SUNTV', 'TEGA', 'BEL', 'EICHERMOT', 'CENTRALBK', 'INTELLECT', 'JINDWORLD', 'POLYPLEX', 'KANSAINER', 'MUTHOOTMF', 'NHPC', 'GRINFRA', 'HCG', 'COFORGE', 'LXCHEM', 'NAVA', 'JKTYRE', 'HARSHA', 'BLS', 'HINDOILEXP', 'KPIL', 'NAUKRI', 'DCBBANK', 'POWERGRID', 'DODLA', 'ADVENZYMES', 'NATCOPHARM', 'EIDPARRY', 'RAYMOND', 'LALPATHLAB', 'JYOTICNC', 'FCL', 'IXIGO', 'HDFCLIFE', 'STARCEMENT', 'IFBIND', 'ADANIPOWER', 'NH', 'ASTRAMICRO', 'FEDERALBNK', 'BAJFINANCE', 'DCMSHRIRAM', 'RATEGAIN', 'M&M', 'KPRMILL', 'MAPMYINDIA', 'SAMHI', 'PERSISTENT', 'BAJAJHIND', 'PATELENG', 'JYOTHYLAB', 'PRUDENT', 'IGL', 'REDINGTON', 'TRENT', 'AUROPHARMA', 'IRCON', 'EPIGRAL', 'KFINTECH', 'BLUEDART', 'TORNTPHARM', 'PRESTIGE', 'SRF', 'LANDMARK', 'RBA', 'MOIL', 'REDTAPE', 'VEDL', 'GODIGIT', 'ALLCARGO', 'ICICIPRULI', 'DOMS', 'POLYMED', 'PRICOLLTD', 'GODREJIND', 'ASAHIINDIA', 'KARURVYSYA', 'BAJAJCON', 'KALAMANDIR', 'CERA', 'BSE', 'INDIGO', 'BAJAJ-AUTO', 'DHANUKA', 'NESTLEIND', 'TATAPOWER', 'SUMICHEM', 'MAZDOCK', 'IFCI', 'ISEC', 'QUESS', 'IIFLCAPS', 'DALBHARAT', 'ADANIPORTS', 'INDUSINDBK', 'POLYCAB', 'TORNTPOWER', 'STLTECH', 'ORIENTCEM', 'JIOFIN', 'M&MFIN', 'ONGC', 'GRANULES', 'UJJIVANSFB', 'DATAMATICS', 'BANKINDIA', 'IEX', 'KPITTECH', 'VTL', 'HAVELLS', 'INFIBEAM', 'VAIBHAVGBL', 'GABRIEL', 'VESUVIUS', 'SBFC', 'SWANENERGY', 'JINDALSAW', 'RESPONIND', 'DATAPATT ...
# 460/750
# ['Date', 'IPCALAB', 'TATAINVEST', 'DEEPAKFERT', 'VSTIND', 'THERMAX', 'INDHOTEL', 'GNFC', 'FSL', 'VENKEYS', 'SSWL', 'AMBUJACEM', 'MRF', 'PGHL', 'HSCL', 'RAMCOCEM', 'FINCABLES', 'ZYDUSLIFE', 'PEL', 'ELGIEQUIP', 'RTNINDIA', 'TCS', 'THOMASCOOK', 'BBTC', 'HDFCBANK', 'DCAL', 'MUTHOOTFIN', 'TRIDENT', 'CGPOWER', 'INDUSTOWER', 'SCHAEFFLER', 'MAITHANALL', 'TIMKEN', 'CEATLTD', 'ZEEL', 'TATACHEM', 'COROMANDEL', 'LMW', 'LUPIN', 'RKFORGE', 'DRREDDY', 'NCC', 'UNOMINDA', 'RENUKA', 'SYMPHONY', 'MMTC', 'ASHOKLEY', 'TATASTEEL', 'BIRLACORPN', 'RELIGARE', 'APLLTD', 'BALAMINES', 'ZYDUSWELL', 'GSPL', 'VOLTAMP', 'CANFINHOME', 'GREAVESCOT', 'NETWORK18', 'TI', 'PURVA', 'SJVN', 'JTEKTINDIA', 'HINDZINC', 'BALKRISIND', 'GRAPHITE', 'SANGHVIMOV', 'EPL', 'JSL', 'SANOFI', 'EXIDEIND', 'MRPL', 'SIEMENS', 'UCOBANK', 'ACC', 'SUNDARMFIN', 'KNRCON', 'CIEINDIA', 'KOTAKBANK', 'LINDEINDIA', 'BHEL', 'GPPL', 'MAHLIFE', 'ITI', 'SCHNEIDER', 'SKFINDIA', 'KSCL', 'RADICO', 'BAJAJELEC', 'APLAPOLLO', 'JMFINANCIL', 'CUB', 'TEXRAIL', 'KEC', 'MANINFRA', 'ICIL', 'TIPSMUSIC', 'OIL', 'MFSL', 'TECHNOE', 'RAJESHEXPO', 'AVANTIFEED', 'GODREJCP', 'SPLPETRO', 'INDIANB', 'TATACOMM', 'ECLERX', 'VEEDOL', 'PGHH', 'HCLTECH', 'CHAMBLFERT', 'TECHM', 'EMAMILTD', 'ASTRAZEN', 'ALOKINDS', 'GODREJPROP', 'KRBL', 'MASTEK', 'GRINDWELL', 'AARTIIND', 'DLF', 'SUDARSCHEM', 'INGERRAND', 'GLAXO', 'MARICO', 'JKLAKSHMI', 'AJANTPHARM', 'ANANTRAJ', 'YESBANK', 'VIPIND', 'KSB', 'WELENT', 'ULTRACEMCO', 'SCI', 'PAGEIND', 'IOC', 'PETRONET', 'NEULANDLAB', 'SAREGAMA', 'DEN', 'GLENMARK', 'NESCO', 'OBEROIRLTY', 'WELCORP', 'DHANI', 'SUNTV', 'BEL', 'EICHERMOT', 'CENTRALBK', 'JINDWORLD', 'POLYPLEX', 'KANSAINER', 'NHPC', 'COFORGE', 'NAVA', 'JKTYRE', 'HINDOILEXP', 'NAUKRI', 'DCBBANK', 'POWERGRID', 'NATCOPHARM', 'EIDPARRY', 'RAYMOND', 'IFBIND', 'ADANIPOWER', 'ASTRAMICRO', 'FEDERALBNK', 'BAJFINANCE', 'DCMSHRIRAM', 'M&M', 'KPRMILL', 'PERSISTENT', 'BAJAJHIND', 'PATELENG', 'JYOTHYLAB', 'IGL', 'REDINGTON', 'TRENT', 'AUROPHARMA', 'BLUEDART', 'TORNTPHARM', 'PRESTIGE', 'SRF', 'MOIL', 'VEDL', 'ALLCARGO', 'POLYMED', 'PRICOLLTD', 'GODREJIND', 'ASAHIINDIA', 'KARURVYSYA', 'BAJAJCON', 'CERA', 'BAJAJ-AUTO', 'DHANUKA', 'NESTLEIND', 'TATAPOWER', 'IFCI', 'ADANIPORTS', 'INDUSINDBK', 'TORNTPOWER', 'STLTECH', 'M&MFIN', 'ONGC', 'GRANULES', 'DATAMATICS', 'BANKINDIA', 'VTL', 'HAVELLS', 'VAIBHAVGBL', 'GABRIEL', 'VESUVIUS', 'SWANENERGY', 'JINDALSAW', 'RESPONIND', 'JAICORPLTD', 'CHENNPETRO', 'POONAWALLA', 'SBIN', 'IMFA', 'BRIGADE', 'BBL', 'WELSPUNLIV', 'UBL', 'RHIM', 'BOSCHLTD', 'COALINDIA', 'SAIL', 'ABBOTINDIA', 'NOCIL', 'HEROMOTOCO', 'BEML', 'IIFL', 'STAR', 'KEI', 'TRITURBINE', 'CENTURYPLY', 'RECLTD', 'AARTIDRUGS', 'WSTCSTPAPR', 'INFY', 'EIHOTEL', 'MARUTI', 'LTF', 'ACE', 'JAMNAAUTO', 'SUNPHARMA', 'ELECTCAST', 'AGI', 'BEPL', 'HERITGFOOD', 'HONAUT', 'GMRAIRPORT', 'BAJAJFINSV', 'SURYAROSNI', 'SHILPAMED', 'WABAG', 'BHARTIARTL', 'WOCKPHARMA', 'FIEMIND', 'GRAVITA', 'KIRLOSENG', 'SUPREMEIND', 'ELECON', 'CESC', 'CANBK', 'ORCHPHARMA', 'TITAN', 'PAISALO', 'ORISSAMINE', 'BASF', 'PIDILITIND', 'MHRIL', 'CIPLA', 'LICHSGFIN', 'SOLARINDS', 'DEEPAKNTR', 'WIPRO', 'CASTROLIND', 'BAYERCROP', 'EVEREADY', 'TVSMOTOR', 'TANLA', 'CGCL', 'SUBROS', 'KSL', 'PFC', 'SHRIRAMFIN', 'FINPIPE', 'SOUTHBANK', 'CONCOR', 'GESHIP', 'INDIAGLYCO', 'ASIANPAINT', 'PIIND', 'HINDUNILVR', 'NTPC', 'CCL', 'RATNAMANI', 'APOLLOHOSP', 'JINDALSTEL', 'ZENSARTECH', 'MOTHERSON', 'JBCHEPHARM', 'JBMA', 'APOLLOTYRE', 'HEIDELBERG', 'APARINDS', 'BOMDYEING', 'ABREL', 'EDELWEISS', 'DBREALTY', 'GPIL', 'SUNDRMFAST', 'BALRAMCHIN', 'GHCL', 'JKIL', 'ATUL', 'PNB', 'JUBLPHARMA', 'IRB', 'TITAGARH', 'HIKAL', 'PFIZER', 'INDIACEM', 'JAIBALAJI', 'SARDAEN', 'MINDACORP', 'TATACONSUM', 'BIOCON', 'RAMKY', 'MANAPPURAM', 'ASTRAL', 'TIRUMALCHM', 'UPL', 'TDPOWERSYS', 'HCC', 'TIMETECHNO', 'NAVINFLUOR', 'TRIVENI', 'GODFRYPHLP', 'IDEA', 'KAJARIACER', 'PHOENIXLTD', 'HEG', 'SUNFLAG', 'SPARC', 'BSOFT', 'DIVISLAB', 'NMDC', 'PCBL', '3MINDIA', 'USHAMART', 'CRISIL', 'TIIL', 'HFCL', 'JKPAPER', 'ICICIBANK', 'MPHASIS', 'MAHABANK', 'SUNTECK', 'JPP ...

# %%
len(listOfColumns)
# Out:
# 750
