# %%
import datetime as dt
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import time
import yfinance as yf

import glob
import os

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
import pickle

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import layers,models

import yfinance as yf
from finvizfinance.quote import finvizfinance

# Avoid Forecasting on Holidays
import holidays

import requests
import bs4

# %%
request=requests.get("https://www.moneycontrol.com/news/relianceindustries/business-RI-6months.html")
print(type(request))
with open("text.html","w",encoding="utf-8") as f:
        f.write(request.text)
# Out:
# <class 'requests.models.Response'>

# %%
# with open("text.html","r") as f:
#     html=f.read()
soup=bs4.BeautifulSoup(request.text,'html.parser')    
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="2" name="next-head-count"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="max-image-preview:large" name="robots">
#    <meta charset="utf-8"/>
#    <title>
#     Business | Latest &amp; Breaking News on Business | Photos, Videos, Breaking Stories and Articles on Business - Moneycontrol.com
#    </title>
#    <meta content="Get all latest &amp; breaking news on Business. Watch videos, top stories and articles on Business at moneycontrol.com." name="description">
#     <meta content="Business News, Business Latest News, Business Trending News, Business News Update" name="news_keywords"/>
#     <meta content="Business News, Business Latest News, Business Trending News, Business News Update" name="Keywords"/>
#     <meta content="NOODP" name="robots"/>
# ...

# %%
soup.title
# Out:
# <title>Business | Latest &amp; Breaking News on Business | Photos, Videos, Breaking Stories and Articles on Business - Moneycontrol.com</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# 'Business | Latest & Breaking News on Business | Photos, Videos, Breaking Stories and Articles on Business - Moneycontrol.com'

# %%
soup.title.parent.name
# Out:
# 'meta'

# %%
soup.p
# Out:
# <p class="my_account">My Account</p>

# %%
soup.a
# Out:
# <a class="lang_link" href="https://www.moneycontrol.com/" title="English">English<span class="arrow down"></span></a>

# %%
soup.find_all('a')
# Out:
# [<a class="lang_link" href="https://www.moneycontrol.com/" title="English">English<span class="arrow down"></span></a>,
#  <a href="https://hindi.moneycontrol.com" target="_blank" title="Hindi">Hindi</a>,
#  <a href="https://gujarati.moneycontrol.com/" target="_blank" title="Gujarati">Gujarati</a>,
#  <a class="specialsbutton" href="javascript:;" title="Specials">Specials<span class="arrow down"></span></a>,
#  <a data-google-interstitial="false" href="https://www.moneycontrolpay.com/" onclick="javascript:GAEventTracker( 'Top Search web', 'Click', 'Lending' ); CleverTapEventTracker( 'Lending', 'Touchpoint', 'Top Search web | ' + window.location.href );" title="Loans up to ₹50 Lakhs"><dotlottie-player autoplay="" background="transparent" loop="" speed="1" src="https://lottie.host/b8dea0d2-ad5d-4ab4-bd9a-f6f914d02847/e23tDL1FuF.json" style="width: 86px; height: 30px"></dotlottie-player></a>,
# ...

# %%
 soup.find(id="newslist-0")
# Out:
# <li class="clearfix" id="newslist-0"> <div class="lazy-container"> <a href="https://www.moneycontrol.com/news/business/companies/reliance-jio-rcomm-deal-will-bring-in-better-fibre-network-for-jio-fitch-ratings-2471151.html" title="Reliance Jio-RCom deal will bring in better fibre network for Jio: Fitch Ratings"><img alt="Reliance Jio-RCom deal will bring in better fibre network for Jio: Fitch Ratings" class="MC_img" data="https://images.moneycontrol.com/static-mcnews/2017/03/reliance_jio_data_network_cellular_mobile_internet_720-770x433.jpg?impolicy=website&amp;width=400&amp;height=225" data-src="https://images.moneycontrol.com/static-mcnews/2017/03/reliance_jio_data_network_cellular_mobile_internet_720-770x433.jpg?impolicy=website&amp;width=400&amp;height=225" height="auto" src="//stat1.moneycontrol.com/mcnews//images/grey_bg.gif?impolicy=website&amp;width=400&amp;height=225" title="Reliance Jio-RCom deal will bring in better fibre network for Jio: Fitch Ratings" width="100%"/></a>
# ...

# %%
soup.get_text
# Out:
# <bound method Tag.get_text of <!DOCTYPE html>
# ...

# %%
# %pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install html5lib
# Out:
# ...
#
# ...

# %%
tag=soup.b
tag.name
# Out:
# 'b'

# %%
soup.a['title']
# Out:
# 'English'

# %%
soup.a['title'] = ['index', 'contents']
print(soup.p)
# Out:
# <p class="my_account">My Account</p>

# %%
x=soup.find_all('a')
x.
