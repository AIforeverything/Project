# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pandas in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: yfinance in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 3)) (0.2.52)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: requests>=2.31 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from yfinance->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from yfinance->-r requirements.txt (line 3)) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from yfinance->-r requirements.txt (line 3)) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from yfinance->-r requirements.txt (line 3)) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from yfinance->-r requirements.txt (line 3)) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from yfinance->-r requirements.txt (line 3)) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from yfinance->-r requirements.txt (line 3)) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from yfinance->-r requirements.txt (line 3)) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance->-r requirements.txt (line 3)) (2.6)
# Requirement already satisfied: six>=1.9 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance->-r requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\om\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 3)) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import datetime as dt
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import time
import yfinance as yf

# %%
df_nifty50=pd.read_csv("MW-NIFTY-50-26-Jan-2025.csv")
df_nifty50.head()
# Out:
#     SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0    NIFTY 50  23,183.90  23,347.30  23,050.00      23,205.35  23,092.20
# 1  HINDUNILVR   2,332.85   2,380.80   2,323.00       2,321.70   2,380.10
# 2   BRITANNIA   5,037.70   5,108.00   5,013.15       5,012.60   5,100.00
# 3   EICHERMOT   5,134.00   5,224.50   5,115.05       5,116.20   5,190.25
# 4      GRASIM   2,466.35   2,514.05   2,453.45       2,461.15   2,495.00
#
#   INDICATIVE CLOSE \n  CHNG \n  %CHNG \n VOLUME \n(shares)  \
# 0                   -  -113.15     -0.49      26,43,36,332
# 1                   -    58.40      2.52         16,88,664
# 2                   -    87.40      1.74          5,09,954
# 3                   -    74.05      1.45          7,30,641
# 4                   -    33.85      1.38         15,10,105
#
#   VALUE \n (₹ Crores)   52W H \n   52W L \n  30 D   %CHNG \n  \
# 0           24,412.33  26,277.35  21,281.45            -2.68
# 1              398.35   3,035.00   2,172.05             1.39
# 2              258.96   6,469.90   4,641.00             7.53
# 3              378.67   5,385.70   3,562.45             8.63
# 4              375.85   2,877.75   2,016.55            -0.44
#
#    365 D % CHNG \n 25-Jan-2024
# 0                         8.15
# 1                        -2.48
# 2                        -0.78
# 3                        43.96
# 4                        19.95

# %%
nifty50Symbols=list(df_nifty50["SYMBOL \n"])
nifty50Symbols=nifty50Symbols[1:] #removing NIFTY 50 symbol
nifty50Symbols
# Out:
# ['HINDUNILVR',
#  'BRITANNIA',
#  'EICHERMOT',
#  'GRASIM',
#  'ICICIBANK',
#  'TATACONSUM',
#  'WIPRO',
#  'TECHM',
#  'POWERGRID',
#  'INFY',
#  'NESTLEIND',
#  'BHARTIARTL',
#  'ITC',
#  'JSWSTEEL',
#  'TCS',
#  'NTPC',
#  'BAJAJ-AUTO',
#  'TATASTEEL',
#  'HDFCLIFE',
#  'TITAN',
#  'HINDALCO',
#  'BAJFINANCE',
#  'SBIN',
#  'AXISBANK',
#  'COALINDIA',
#  'ASIANPAINT',
#  'KOTAKBANK',
#  'HCLTECH',
#  'MARUTI',
#  'SUNPHARMA',
#  'BAJAJFINSV',
#  'ADANIPORTS',
#  'SHRIRAMFIN',
#  'SBILIFE',
#  'ULTRACEMCO',
#  'HDFCBANK',
#  'HEROMOTOCO',
#  'LT',
#  'BEL',
#  'RELIANCE',
#  'ONGC',
#  'INDUSINDBK',
#  'CIPLA',
#  'TATAMOTORS',
#  'APOLLOHOSP',
#  'BPCL',
#  'ADANIENT',
#  'M&M',
#  'TRENT',
#  'DRREDDY']

# %%
#converting every stock name as .NSE to get yahoo finance info
for i in range(len(nifty50Symbols)):
    nifty50Symbols[i]+='.ns'
    
nifty50Symbols
# Out:
# ['HINDUNILVR.ns',
#  'BRITANNIA.ns',
#  'EICHERMOT.ns',
#  'GRASIM.ns',
#  'ICICIBANK.ns',
#  'TATACONSUM.ns',
#  'WIPRO.ns',
#  'TECHM.ns',
#  'POWERGRID.ns',
#  'INFY.ns',
#  'NESTLEIND.ns',
#  'BHARTIARTL.ns',
#  'ITC.ns',
#  'JSWSTEEL.ns',
#  'TCS.ns',
#  'NTPC.ns',
#  'BAJAJ-AUTO.ns',
#  'TATASTEEL.ns',
#  'HDFCLIFE.ns',
#  'TITAN.ns',
#  'HINDALCO.ns',
#  'BAJFINANCE.ns',
#  'SBIN.ns',
#  'AXISBANK.ns',
#  'COALINDIA.ns',
#  'ASIANPAINT.ns',
#  'KOTAKBANK.ns',
#  'HCLTECH.ns',
#  'MARUTI.ns',
#  'SUNPHARMA.ns',
#  'BAJAJFINSV.ns',
#  'ADANIPORTS.ns',
#  'SHRIRAMFIN.ns',
#  'SBILIFE.ns',
#  'ULTRACEMCO.ns',
#  'HDFCBANK.ns',
#  'HEROMOTOCO.ns',
#  'LT.ns',
#  'BEL.ns',
#  'RELIANCE.ns',
#  'ONGC.ns',
#  'INDUSINDBK.ns',
#  'CIPLA.ns',
#  'TATAMOTORS.ns',
#  'APOLLOHOSP.ns',
#  'BPCL.ns',
#  'ADANIENT.ns',
#  'M&M.ns',
#  'TRENT.ns',
#  'DRREDDY.ns']

# %%
#checking the stock details
def get_info(ticker):
    stock=yf.Ticker(ticker)
    print(stock.info)

# %%
# for i in nifty50Symbols:
#     print(get_info(i))

# %%
def save_csv(stock_name):
    stock=yf.Ticker(stock_name)
    df=stock.history(period="20y")["Close"]
    file=stock_name.replace(".","_")+".csv"
    df.to_csv(file)

# %%
for stock in nifty50Symbols:
    save_csv(stock)
